# %%
import pandas as pd
from typing import Tuple
import lxml.html
import re

df_header = pd.read_csv('data/2018-07-15-content.csv')
df_header.head(5)
# Out:
#    Unnamed: 0                    id  \
# 0           0  1a7920d0dbc2099db000
# 1           1  5414e0beb7df9908949d
# 2           2  79679ad9911da6ea0309
# 3           3  04a22e200cbb0170be77
# 4           4  73cf2708b31c4cb901ec
#
#                                                 text  \
# 0  はじめには、モックのサービスを作成して、実際にシナリオテストを実施してみました。今回は、テス...
# 1  久々のQiita投稿です。淫夢記事しか投稿してないのはまずいかなと思ってまともな記事を1つシ...
# 2  私は現在、Scalaで書かれているわりと古めのゲーム用サーバーに、いろいろ機能追加したり不具...
# 3  提案 - Issue -いいねが付く記事は、有用な記事。誰かの役に立っている記事 のはずだ。...
# 4  URL直打ちとはそのままURLに直接打ち込むこと。対策していないと、他のユーザーが自分のペー...
#
#                                           code-frame  \
# 0  Scenario: Normal def\n\n* def text = 'karate e...
# 1  \n# # notepadの位置を確認\n$ which notepad.exe\n/mnt...
# 2  command: findAndModify { findandmodify: "chara...
# 3                                                NaN
# 4  \ndef correct_user\n  @micropost = current_use...
#
#                                                 lang  \
# 0  cucumber,cucumber,cucumber,cucumber,cucumber,c...
# 1                                              sh,sh
# 2                                            js,text
# 3                                                NaN
# 4                                         rb,ruby,rb
#
#                                                 code  \
# 0  def,print,match,""",jsonData,set,table,set,tab...
# 1                                                NaN
# 2  var,findAndModify,findAndModify,findAndModify,...
# 3                                                NaN
# 4                                                NaN
#
#                                               a-text  \
# 0  前回（#03 Writing Scenarios）,https://github.com/i...
# 1             WSLのbashからWindowsの実行ファイルを実行する | yuipro
# 2  Goでテストクライアントを書いたり,1,Goでテストクライアントを書くことで、安価なLinu...
# 3  ド素人のための Travis CI の使い方,Webアプリを作る人へ！UIの重要性 ~Web...
# 4                                                NaN
#
#                                               a-href
# 0  #%E3%81%AF%E3%81%98%E3%82%81%E3%81%AB,https://...
# 1  https://yuis-programming.com/2018/06/19/wsl%e3...
# 2  https://qiita.com/yonezawaizumi/items/01384aad...
# 3  #%E6%8F%90%E6%A1%88---issue--,#%E3%83%88%E3%83...
# 4  #url%E7%9B%B4%E6%89%93%E3%81%A1%E3%81%A8%E3%81...

# %%
df_header.isna().sum()
# Out:
# Unnamed: 0       0
# id               0
# text            16
# code-frame     850
# lang           856
# code          2122
# a-text         979
# a-href         233
# dtype: int64

# %%
df_nonna = df_header[df_header['text'].isna() == False]
df_nonna.isna().sum()
# Out:
# Unnamed: 0       0
# id               0
# text             0
# code-frame     845
# lang           851
# code          2106
# a-text         969
# a-href         226
# dtype: int64

# %%
import MeCab
tagger = MeCab.Tagger()
tagger.parse('')

node = tagger.parseToNode(df_header['text'][0])

# %%
hinshi_list = ['名詞','動詞','形容詞']
words = []
woo = []
while node:
    pos, pos_sub1 = node.feature.split(',')[:2]
#     print(pos, pos_sub1)
    if pos in hinshi_list:
        woo.append(node.surface)
    if pos == '名詞' and pos_sub1 in ('固有名詞', '一般'):
        words.append(node.surface)

    print(node.surface, node.feature)
    node = node.next
# Out:
#  BOS/EOS,*,*,*,*,*,*,*,*
# はじめ 名詞,副詞可能,*,*,*,*,はじめ,ハジメ,ハジメ
# に 助詞,格助詞,一般,*,*,*,に,ニ,ニ
# は 助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、 記号,読点,*,*,*,*,、,、,、
# モック 名詞,一般,*,*,*,*,*
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# サービス 名詞,サ変接続,*,*,*,*,サービス,サービス,サービス
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 作成 名詞,サ変接続,*,*,*,*,作成,サクセイ,サクセイ
# し 動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て 助詞,接続助詞,*,*,*,*,て,テ,テ
# 、 記号,読点,*,*,*,*,、,、,、
# 実際 副詞,助詞類接続,*,*,*,*,実際,ジッサイ,ジッサイ
# に 助詞,副詞化,*,*,*,*,に,ニ,ニ
# シナリオ 名詞,一般,*,*,*,*,シナリオ,シナリオ,シナリオ
# テスト 名詞,サ変接続,*,*,*,*,テスト,テスト,テスト
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 実施 名詞,サ変接続,*,*,*,*,実施,ジッシ,ジッシ
# し 動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て 助詞,接続助詞,*,*,*,*,て,テ,テ
# み 動詞,非自立,*,*,一段,連用形,みる,ミ,ミ
# まし 助動詞,*,*,*,特殊・マス,連用形,ます,マシ,マシ
# た 助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 。 記号,句点,*,*,*,*,。,。,。
# 今回 名詞,副詞可能,*,*,*,*,今回,コンカイ,コンカイ
# は 助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、 記号,読点,*,*,*,*,、,、,、
# テスト 名詞,サ変接続,*,*,*,*,テスト,テスト,テスト
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 幅 名詞,一般,*,*,*,*,幅,ハバ,ハバ
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 広げる 動詞,自立,*,*,一段,基本形,広げる,ヒロゲル,ヒロゲル
# ため 名詞,非自立,副詞可能,*,*,*,ため,タメ,タメ
# に 助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 、 記号,読点,*,*,*,*,、,、,、
# Karate 名詞,一般,*,*,*,*,*
# で 助詞,格助詞,一般,*,*,*,で,デ,デ
# 、 記号,読点,*,*,*,*,、,、,、
# どの 連体詞,*,*,*,*,*,どの,ドノ,ドノ
# よう 名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー
# に 助詞,副詞化,*,*,*,*,に,ニ,ニ
# データ 名詞,一般,*,*,*,*,データ,データ,データ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 定義 名詞,サ変接続,*,*,*,*,定義,テイギ,テイギ
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# する 動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# の 名詞,非自立,一般,*,*,*,の,ノ,ノ
# か 助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 確認 名詞,サ変接続,*,*,*,*,確認,カクニン,カクニン
# し 動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て 助詞,接続助詞,*,*,*,*,て,テ,テ
# み 動詞,非自立,*,*,一段,連用形,みる,ミ,ミ
# ます 助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。 記号,句点,*,*,*,*,。,。,。
# テスト 名詞,サ変接続,*,*,*,*,テスト,テスト,テスト
# 実施 名詞,サ変接続,*,*,*,*,実施,ジッシ,ジッシ
# 時 名詞,接尾,副詞可能,*,*,*,時,ジ,ジ
# に 助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 、 記号,読点,*,*,*,*,、,、,、
# リクエスト 名詞,一般,*,*,*,*,リクエスト,リクエスト,リクエスト
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 内容 名詞,一般,*,*,*,*,内容,ナイヨウ,ナイヨー
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 指定 名詞,サ変接続,*,*,*,*,指定,シテイ,シテイ
# し 動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# たり 助詞,並立助詞,*,*,*,*,たり,タリ,タリ
# 、 記号,読点,*,*,*,*,、,、,、
# レスポンス 名詞,一般,*,*,*,*,レスポンス,レスポンス,レスポンス
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 内容 名詞,一般,*,*,*,*,内容,ナイヨウ,ナイヨー
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 確認 名詞,サ変接続,*,*,*,*,確認,カクニン,カクニン
# し 動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# たり 助詞,並立助詞,*,*,*,*,たり,タリ,タリ
# する 動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# ため 名詞,非自立,副詞可能,*,*,*,ため,タメ,タメ
# に 助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 、 記号,読点,*,*,*,*,、,、,、
# どの 連体詞,*,*,*,*,*,どの,ドノ,ドノ
# よう 名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー
# に 助詞,副詞化,*,*,*,*,に,ニ,ニ
# データ 名詞,一般,*,*,*,*,データ,データ,データ
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 定義 名詞,サ変接続,*,*,*,*,定義,テイギ,テイギ
# する 動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# の 名詞,非自立,一般,*,*,*,の,ノ,ノ
# か 助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# 、 記号,読点,*,*,*,*,、,、,、
# という 助詞,格助詞,連語,*,*,*,という,トイウ,トユウ
# こと 名詞,非自立,一般,*,*,*,こと,コト,コト
# に 助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なり 動詞,自立,*,*,五段・ラ行,連用形,なる,ナリ,ナリ
# ます 助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。 記号,句点,*,*,*,*,。,。,。
# データ 名詞,一般,*,*,*,*,データ,データ,データ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 指定 名詞,サ変接続,*,*,*,*,指定,シテイ,シテイ
# 方法 名詞,一般,*,*,*,*,方法,ホウホウ,ホーホー
# 変数 名詞,一般,*,*,*,*,変数,ヘンスウ,ヘンスー
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 指定 名詞,サ変接続,*,*,*,*,指定,シテイ,シテイ
# まずは 接続詞,*,*,*,*,*,まずは,マズハ,マズワ
# 、 記号,読点,*,*,*,*,、,、,、
# 基本 名詞,一般,*,*,*,*,基本,キホン,キホン
# 的 名詞,接尾,形容動詞語幹,*,*,*,的,テキ,テキ
# な 助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# 定義 名詞,サ変接続,*,*,*,*,定義,テイギ,テイギ
# として 助詞,格助詞,連語,*,*,*,として,トシテ,トシテ
# 、 記号,読点,*,*,*,*,、,、,、
# 変数 名詞,一般,*,*,*,*,変数,ヘンスウ,ヘンスー
# で 助詞,格助詞,一般,*,*,*,で,デ,デ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 指定 名詞,サ変接続,*,*,*,*,指定,シテイ,シテイ
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# し 動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て 助詞,接続助詞,*,*,*,*,て,テ,テ
# み 動詞,非自立,*,*,一段,連用形,みる,ミ,ミ
# ます 助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。 記号,句点,*,*,*,*,。,。,。
# が 接続詞,*,*,*,*,*,が,ガ,ガ
# 、 記号,読点,*,*,*,*,、,、,、
# 変数 名詞,一般,*,*,*,*,変数,ヘンスウ,ヘンスー
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 定義 名詞,サ変接続,*,*,*,*,定義,テイギ,テイギ
# です 助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。 記号,句点,*,*,*,*,。,。,。
# は 助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、 記号,読点,*,*,*,*,、,、,、
# テスト 名詞,サ変接続,*,*,*,*,テスト,テスト,テスト
# 実行 名詞,サ変接続,*,*,*,*,実行,ジッコウ,ジッコー
# 時 名詞,接尾,副詞可能,*,*,*,時,ジ,ジ
# に 助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 、 記号,読点,*,*,*,*,、,、,、
# レポート 名詞,サ変接続,*,*,*,*,レポート,レポート,レポート
# に 助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 変数 名詞,一般,*,*,*,*,変数,ヘンスウ,ヘンスー
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 内容 名詞,一般,*,*,*,*,内容,ナイヨウ,ナイヨー
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 出力 名詞,サ変接続,*,*,*,*,出力,シュツリョク,シュツリョク
# し 動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て 助詞,接続助詞,*,*,*,*,て,テ,テ
# くれ 動詞,非自立,*,*,一段・クレル,連用形,くれる,クレ,クレ
# ます 助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。 記号,句点,*,*,*,*,。,。,。
# は 助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、 記号,読点,*,*,*,*,、,、,、
# 値 名詞,一般,*,*,*,*,値,ネ,ネ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 確認 名詞,サ変接続,*,*,*,*,確認,カクニン,カクニン
# です 助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。 記号,句点,*,*,*,*,。,。,。
# 実行 名詞,サ変接続,*,*,*,*,実行,ジッコウ,ジッコー
# し 動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た 助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# とき 名詞,非自立,副詞可能,*,*,*,とき,トキ,トキ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# レポート 名詞,サ変接続,*,*,*,*,レポート,レポート,レポート
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 内容 名詞,一般,*,*,*,*,内容,ナイヨウ,ナイヨー
# は 助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、 記号,読点,*,*,*,*,、,、,、
# 以下 名詞,非自立,副詞可能,*,*,*,以下,イカ,イカ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# よう 名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー
# な 助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# 感じ 名詞,一般,*,*,*,*,感じ,カンジ,カンジ
# です 助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。 記号,句点,*,*,*,*,。,。,。
# 問題 名詞,ナイ形容詞語幹,*,*,*,*,問題,モンダイ,モンダイ
# なく 助動詞,*,*,*,特殊・ナイ,連用テ接続,ない,ナク,ナク
# 、 記号,読点,*,*,*,*,、,、,、
# テスト 名詞,サ変接続,*,*,*,*,テスト,テスト,テスト
# が 助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 通っ 動詞,自立,*,*,五段・ワ行促音便,連用タ接続,通う,カヨッ,カヨッ
# て 助詞,接続助詞,*,*,*,*,て,テ,テ
# い 動詞,非自立,*,*,一段,連用形,いる,イ,イ
# ます 助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# ね 助詞,終助詞,*,*,*,*,ね,ネ,ネ
# 。 記号,句点,*,*,*,*,。,。,。
# 当然 副詞,助詞類接続,*,*,*,*,当然,トウゼン,トーゼン
# ながら 助詞,接続助詞,*,*,*,*,ながら,ナガラ,ナガラ
# 、 記号,読点,*,*,*,*,、,、,、
# 日本語 名詞,一般,*,*,*,*,日本語,ニホンゴ,ニホンゴ
# も 助詞,係助詞,*,*,*,*,も,モ,モ
# 問題 名詞,ナイ形容詞語幹,*,*,*,*,問題,モンダイ,モンダイ
# なく 助動詞,*,*,*,特殊・ナイ,連用テ接続,ない,ナク,ナク
# 利用 名詞,サ変接続,*,*,*,*,利用,リヨウ,リヨー
# でき 動詞,自立,*,*,一段,連用形,できる,デキ,デキ
# ます 助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。 記号,句点,*,*,*,*,。,。,。
# JSON 名詞,一般,*,*,*,*,*
# 形式 名詞,一般,*,*,*,*,形式,ケイシキ,ケイシキ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# データ 名詞,一般,*,*,*,*,データ,データ,データ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 指定 名詞,サ変接続,*,*,*,*,指定,シテイ,シテイ
# 次 名詞,接尾,一般,*,*,*,次,ジ,ジ
# は 助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、 記号,読点,*,*,*,*,、,、,、
# JSON 名詞,固有名詞,組織,*,*,*,*
# データ 名詞,一般,*,*,*,*,データ,データ,データ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 指定 名詞,サ変接続,*,*,*,*,指定,シテイ,シテイ
# 方法 名詞,一般,*,*,*,*,方法,ホウホウ,ホーホー
# について 助詞,格助詞,連語,*,*,*,について,ニツイテ,ニツイテ
# 確認 名詞,サ変接続,*,*,*,*,確認,カクニン,カクニン
# し 動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# ます 助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。 記号,句点,*,*,*,*,。,。,。
# REST 名詞,一般,*,*,*,*,*
# - 名詞,サ変接続,*,*,*,*,*
# API 名詞,一般,*,*,*,*,*
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# テスト 名詞,サ変接続,*,*,*,*,テスト,テスト,テスト
# に 助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 向け 動詞,自立,*,*,一段,連用形,向ける,ムケ,ムケ
# て 助詞,接続助詞,*,*,*,*,て,テ,テ
# は 助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、 記号,読点,*,*,*,*,、,、,、
# この 連体詞,*,*,*,*,*,この,コノ,コノ
# 辺り 名詞,一般,*,*,*,*,辺り,アタリ,アタリ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 使い勝手 名詞,一般,*,*,*,*,使い勝手,ツカイガッテ,ツカイガッテ
# は 助詞,係助詞,*,*,*,*,は,ハ,ワ
# 重要 名詞,形容動詞語幹,*,*,*,*,重要,ジュウヨウ,ジューヨー
# です 助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# ね 助詞,終助詞,*,*,*,*,ね,ネ,ネ
# 。 記号,句点,*,*,*,*,。,。,。
# 基本 名詞,一般,*,*,*,*,基本,キホン,キホン
# 的 名詞,接尾,形容動詞語幹,*,*,*,的,テキ,テキ
# な 助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# 指定 名詞,サ変接続,*,*,*,*,指定,シテイ,シテイ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 仕方 名詞,ナイ形容詞語幹,*,*,*,*,仕方,シカタ,シカタ
# として 助詞,格助詞,連語,*,*,*,として,トシテ,トシテ
# 、 記号,読点,*,*,*,*,、,、,、
# マルチ 名詞,一般,*,*,*,*,マルチ,マルチ,マルチ
# ライン 名詞,一般,*,*,*,*,ライン,ライン,ライン
# で 助詞,格助詞,一般,*,*,*,で,デ,デ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 指定 名詞,サ変接続,*,*,*,*,指定,シテイ,シテイ
# です 助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。 記号,句点,*,*,*,*,。,。,。
# で 助詞,格助詞,一般,*,*,*,で,デ,デ
# 囲む 動詞,自立,*,*,五段・マ行,基本形,囲む,カコム,カコム
# こと 名詞,非自立,一般,*,*,*,こと,コト,コト
# によって 助詞,格助詞,連語,*,*,*,によって,ニヨッテ,ニヨッテ
# 、 記号,読点,*,*,*,*,、,、,、
# マルチ 名詞,一般,*,*,*,*,マルチ,マルチ,マルチ
# ライン 名詞,一般,*,*,*,*,ライン,ライン,ライン
# で 助詞,格助詞,一般,*,*,*,で,デ,デ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# データ 名詞,一般,*,*,*,*,データ,データ,データ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 指定 名詞,サ変接続,*,*,*,*,指定,シテイ,シテイ
# が 助詞,格助詞,一般,*,*,*,が,ガ,ガ
# でき 動詞,自立,*,*,一段,連用形,できる,デキ,デキ
# て 助詞,接続助詞,*,*,*,*,て,テ,テ
# い 動詞,非自立,*,*,一段,連用形,いる,イ,イ
# ます 助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。 記号,句点,*,*,*,*,。,。,。
# 先程 名詞,副詞可能,*,*,*,*,先程,サキホド,サキホド
# 指定 名詞,サ変接続,*,*,*,*,指定,シテイ,シテイ
# し 動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た 助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# データ 名詞,一般,*,*,*,*,データ,データ,データ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 一部 名詞,副詞可能,*,*,*,*,一部,イチブ,イチブ
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 変更 名詞,サ変接続,*,*,*,*,変更,ヘンコウ,ヘンコー
# し 動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て 助詞,接続助詞,*,*,*,*,て,テ,テ
# い 動詞,非自立,*,*,一段,連用形,いる,イ,イ
# ます 助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。 記号,句点,*,*,*,*,。,。,。
# コマンド 名詞,一般,*,*,*,*,コマンド,コマンド,コマンド
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 利用 名詞,サ変接続,*,*,*,*,利用,リヨウ,リヨー
# する 動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# こと 名詞,非自立,一般,*,*,*,こと,コト,コト
# で 助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ
# 、 記号,読点,*,*,*,*,、,、,、
# データ 名詞,一般,*,*,*,*,データ,データ,データ
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 変更 名詞,サ変接続,*,*,*,*,変更,ヘンコウ,ヘンコー
# でき 動詞,自立,*,*,一段,連用形,できる,デキ,デキ
# ます 助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。 記号,句点,*,*,*,*,。,。,。
# 今度 名詞,副詞可能,*,*,*,*,今度,コンド,コンド
# は 助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、 記号,読点,*,*,*,*,、,、,、
# テーブル 名詞,一般,*,*,*,*,テーブル,テーブル,テーブル
# 形式 名詞,一般,*,*,*,*,形式,ケイシキ,ケイシキ
# で 助詞,格助詞,一般,*,*,*,で,デ,デ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# JSON 名詞,一般,*,*,*,*,*
# データ 名詞,一般,*,*,*,*,データ,データ,データ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 指定 名詞,サ変接続,*,*,*,*,指定,シテイ,シテイ
# です 助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。 記号,句点,*,*,*,*,。,。,。
# コマンド 名詞,一般,*,*,*,*,コマンド,コマンド,コマンド
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 指定 名詞,サ変接続,*,*,*,*,指定,シテイ,シテイ
# し 動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て 助詞,接続助詞,*,*,*,*,て,テ,テ
# 定義 名詞,サ変接続,*,*,*,*,定義,テイギ,テイギ
# し 動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て 助詞,接続助詞,*,*,*,*,て,テ,テ
# い 動詞,非自立,*,*,一段,連用形,いる,イ,イ
# ます 助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。 記号,句点,*,*,*,*,。,。,。
# 生 名詞,形容動詞語幹,*,*,*,*,生,ナマ,ナマ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# JSON 名詞,一般,*,*,*,*,*
# データ 名詞,一般,*,*,*,*,データ,データ,データ
# より 助詞,格助詞,一般,*,*,*,より,ヨリ,ヨリ
# も 助詞,係助詞,*,*,*,*,も,モ,モ
# 、 記号,読点,*,*,*,*,、,、,、
# こちら 名詞,代名詞,一般,*,*,*,こちら,コチラ,コチラ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 方 名詞,非自立,一般,*,*,*,方,ホウ,ホー
# が 助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 見 動詞,自立,*,*,一段,連用形,見る,ミ,ミ
# やすい 形容詞,非自立,*,*,形容詞・アウオ段,基本形,やすい,ヤスイ,ヤスイ
# です 助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# ね 助詞,終助詞,*,*,*,*,ね,ネ,ネ
# 。 記号,句点,*,*,*,*,。,。,。
# ただ 接続詞,*,*,*,*,*,ただ,タダ,タダ
# 、 記号,読点,*,*,*,*,、,、,、
# table 名詞,固有名詞,組織,*,*,*,*
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 場合 名詞,副詞可能,*,*,*,*,場合,バアイ,バアイ
# 、 記号,読点,*,*,*,*,、,、,、
# ネスト 名詞,一般,*,*,*,*,ネスト,ネスト,ネスト
# さ 動詞,自立,*,*,サ変・スル,未然レル接続,する,サ,サ
# れ 動詞,接尾,*,*,一段,連用形,れる,レ,レ
# て 助詞,接続助詞,*,*,*,*,て,テ,テ
# いる 動詞,非自立,*,*,一段,基本形,いる,イル,イル
# よう 名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー
# な 助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# JSON 名詞,一般,*,*,*,*,*
# は 助詞,係助詞,*,*,*,*,は,ハ,ワ
# 定義 名詞,サ変接続,*,*,*,*,定義,テイギ,テイギ
# でき 動詞,自立,*,*,一段,連用形,できる,デキ,デキ
# ませ 助動詞,*,*,*,特殊・マス,未然形,ます,マセ,マセ
# ん 助動詞,*,*,*,不変化型,基本形,ん,ン,ン
# 。 記号,句点,*,*,*,*,。,。,。
# ネスト 名詞,一般,*,*,*,*,ネスト,ネスト,ネスト
# さ 動詞,自立,*,*,サ変・スル,未然レル接続,する,サ,サ
# れ 動詞,接尾,*,*,一段,連用形,れる,レ,レ
# た 助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# JSON 名詞,一般,*,*,*,*,*
# データ 名詞,一般,*,*,*,*,データ,データ,データ
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 定義 名詞,サ変接続,*,*,*,*,定義,テイギ,テイギ
# し 動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# たい 助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ
# 場合 名詞,副詞可能,*,*,*,*,場合,バアイ,バアイ
# は 助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、 記号,読点,*,*,*,*,、,、,、
# コマンド 名詞,一般,*,*,*,*,コマンド,コマンド,コマンド
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 利用 名詞,サ変接続,*,*,*,*,利用,リヨウ,リヨー
# する 動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# こと 名詞,非自立,一般,*,*,*,こと,コト,コト
# で 助詞,格助詞,一般,*,*,*,で,デ,デ
# 可能 名詞,形容動詞語幹,*,*,*,*,可能,カノウ,カノー
# です 助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。 記号,句点,*,*,*,*,。,。,。
# こちら 名詞,代名詞,一般,*,*,*,こちら,コチラ,コチラ
# も 助詞,係助詞,*,*,*,*,も,モ,モ
# 、 記号,読点,*,*,*,*,、,、,、
# テーブル 名詞,一般,*,*,*,*,テーブル,テーブル,テーブル
# 形式 名詞,一般,*,*,*,*,形式,ケイシキ,ケイシキ
# に 助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 近い 形容詞,自立,*,*,形容詞・アウオ段,基本形,近い,チカイ,チカイ
# 内容 名詞,一般,*,*,*,*,内容,ナイヨウ,ナイヨー
# です 助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# が 助詞,接続助詞,*,*,*,*,が,ガ,ガ
# 、 記号,読点,*,*,*,*,、,、,、
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# とき 名詞,非自立,副詞可能,*,*,*,とき,トキ,トキ
# と 助詞,格助詞,引用,*,*,*,と,ト,ト
# 比べ 動詞,自立,*,*,一段,連用形,比べる,クラベ,クラベ
# て 助詞,接続助詞,*,*,*,*,て,テ,テ
# 、 記号,読点,*,*,*,*,、,、,、
# 行 名詞,一般,*,*,*,*,行,クダリ,クダリ
# と 助詞,並立助詞,*,*,*,*,と,ト,ト
# 列 名詞,一般,*,*,*,*,列,レツ,レツ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 指定 名詞,サ変接続,*,*,*,*,指定,シテイ,シテイ
# が 助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 入れ替わっ 動詞,自立,*,*,五段・ラ行,連用タ接続,入れ替わる,イレカワッ,イレカワッ
# て 助詞,接続助詞,*,*,*,*,て,テ,テ
# いる 動詞,非自立,*,*,一段,基本形,いる,イル,イル
# こと 名詞,非自立,一般,*,*,*,こと,コト,コト
# に 助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 注意 名詞,サ変接続,*,*,*,*,注意,チュウイ,チューイ
# し 動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て 助詞,接続助詞,*,*,*,*,て,テ,テ
# ください 動詞,非自立,*,*,五段・ラ行特殊,命令ｉ,くださる,クダサイ,クダサイ
# 。 記号,句点,*,*,*,*,。,。,。
# テスト 名詞,サ変接続,*,*,*,*,テスト,テスト,テスト
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 実行 名詞,サ変接続,*,*,*,*,実行,ジッコウ,ジッコー
# 結果 名詞,副詞可能,*,*,*,*,結果,ケッカ,ケッカ
# は 助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、 記号,読点,*,*,*,*,、,、,、
# 以下 名詞,非自立,副詞可能,*,*,*,以下,イカ,イカ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# よう 名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー
# に 助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なり 動詞,自立,*,*,五段・ラ行,連用形,なる,ナリ,ナリ
# ます 助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。 記号,句点,*,*,*,*,。,。,。
# 指定 名詞,サ変接続,*,*,*,*,指定,シテイ,シテイ
# し 動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た 助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# データ 名詞,一般,*,*,*,*,データ,データ,データ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 内容 名詞,一般,*,*,*,*,内容,ナイヨウ,ナイヨー
# も 助詞,係助詞,*,*,*,*,も,モ,モ
# 確認 名詞,サ変接続,*,*,*,*,確認,カクニン,カクニン
# でき 動詞,自立,*,*,一段,連用形,できる,デキ,デキ
# て 助詞,接続助詞,*,*,*,*,て,テ,テ
# 、 記号,読点,*,*,*,*,、,、,、
# 分かり 動詞,自立,*,*,五段・ラ行,連用形,分かる,ワカリ,ワカリ
# やすい 形容詞,非自立,*,*,形容詞・アウオ段,基本形,やすい,ヤスイ,ヤスイ
# です 助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。 記号,句点,*,*,*,*,。,。,。
# パラメータ 名詞,一般,*,*,*,*,パラメータ,パラメータ,パラメータ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 置換 名詞,サ変接続,*,*,*,*,置換,チカン,チカン
# 上記 名詞,一般,*,*,*,*,上記,ジョウキ,ジョーキ
# で 助詞,格助詞,一般,*,*,*,で,デ,デ
# 、 記号,読点,*,*,*,*,、,、,、
# コマンド 名詞,一般,*,*,*,*,コマンド,コマンド,コマンド
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 利用 名詞,サ変接続,*,*,*,*,利用,リヨウ,リヨー
# し 動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た 助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 変数 名詞,一般,*,*,*,*,変数,ヘンスウ,ヘンスー
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 値 名詞,一般,*,*,*,*,値,ネ,ネ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 変換 名詞,サ変接続,*,*,*,*,変換,ヘンカン,ヘンカン
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 実施 名詞,サ変接続,*,*,*,*,実施,ジッシ,ジッシ
# し 動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# まし 助動詞,*,*,*,特殊・マス,連用形,ます,マシ,マシ
# た 助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# が 助詞,接続助詞,*,*,*,*,が,ガ,ガ
# 、 記号,読点,*,*,*,*,、,、,、
# 指定 名詞,サ変接続,*,*,*,*,指定,シテイ,シテイ
# し 動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た 助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 変数 名詞,一般,*,*,*,*,変数,ヘンスウ,ヘンスー
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 一部 名詞,副詞可能,*,*,*,*,一部,イチブ,イチブ
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 置き換える 動詞,自立,*,*,一段,基本形,置き換える,オキカエル,オキカエル
# よう 名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー
# な 助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# こと 名詞,非自立,一般,*,*,*,こと,コト,コト
# （ 記号,括弧開,*,*,*,*,（,（,（
# 例えば 接続詞,*,*,*,*,*,例えば,タトエバ,タトエバ
# 、 記号,読点,*,*,*,*,、,、,、
# 文字 名詞,一般,*,*,*,*,文字,モジ,モジ
# 列 名詞,一般,*,*,*,*,列,レツ,レツ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 一部分 名詞,一般,*,*,*,*,一部分,イチブブン,イチブブン
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 変更 名詞,サ変接続,*,*,*,*,変更,ヘンコウ,ヘンコー
# し 動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た 助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 場合 名詞,副詞可能,*,*,*,*,場合,バアイ,バアイ
# など 助詞,副助詞,*,*,*,*,など,ナド,ナド
# ） 記号,括弧閉,*,*,*,*,）,）,）
# は 助詞,係助詞,*,*,*,*,は,ハ,ワ
# でき 動詞,自立,*,*,一段,連用形,できる,デキ,デキ
# ませ 助動詞,*,*,*,特殊・マス,未然形,ます,マセ,マセ
# ん 助動詞,*,*,*,不変化型,基本形,ん,ン,ン
# 。 記号,句点,*,*,*,*,。,。,。
# その 連体詞,*,*,*,*,*,その,ソノ,ソノ
# よう 名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー
# な 助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# 置換 名詞,サ変接続,*,*,*,*,置換,チカン,チカン
# として 助詞,格助詞,連語,*,*,*,として,トシテ,トシテ
# は 助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、 記号,読点,*,*,*,*,、,、,、
# 別 名詞,一般,*,*,*,*,別,ベツ,ベツ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 方法 名詞,一般,*,*,*,*,方法,ホウホウ,ホーホー
# が 助詞,格助詞,一般,*,*,*,が,ガ,ガ
# あり 動詞,自立,*,*,五段・ラ行,連用形,ある,アリ,アリ
# ます 助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。 記号,句点,*,*,*,*,。,。,。
# コマンド 名詞,一般,*,*,*,*,コマンド,コマンド,コマンド
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 利用 名詞,サ変接続,*,*,*,*,利用,リヨウ,リヨー
# する 動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# と 助詞,接続助詞,*,*,*,*,と,ト,ト
# 、 記号,読点,*,*,*,*,、,、,、
# 予め 副詞,一般,*,*,*,*,予め,アラカジメ,アラカジメ
# 置換 名詞,サ変接続,*,*,*,*,置換,チカン,チカン
# 変数 名詞,一般,*,*,*,*,変数,ヘンスウ,ヘンスー
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 指定 名詞,サ変接続,*,*,*,*,指定,シテイ,シテイ
# し 動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て 助詞,接続助詞,*,*,*,*,て,テ,テ
# おき 動詞,非自立,*,*,五段・カ行イ音便,連用形,おく,オキ,オキ
# 、 記号,読点,*,*,*,*,、,、,、
# それ 名詞,代名詞,一般,*,*,*,それ,ソレ,ソレ
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 指定 名詞,サ変接続,*,*,*,*,指定,シテイ,シテイ
# し 動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た 助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 値 名詞,一般,*,*,*,*,値,ネ,ネ
# で 助詞,格助詞,一般,*,*,*,で,デ,デ
# 置換 名詞,サ変接続,*,*,*,*,置換,チカン,チカン
# する 動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# よう 名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー
# な 助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# こと 名詞,非自立,一般,*,*,*,こと,コト,コト
# が 助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 可能 名詞,形容動詞語幹,*,*,*,*,可能,カノウ,カノー
# です 助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。 記号,句点,*,*,*,*,。,。,。
# デフォルト 名詞,一般,*,*,*,*,デフォルト,デフォルト,デフォルト
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 変数 名詞,一般,*,*,*,*,変数,ヘンスウ,ヘンスー
# は 助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、 記号,読点,*,*,*,*,、,、,、
# という 助詞,格助詞,連語,*,*,*,という,トイウ,トユウ
# 形式 名詞,一般,*,*,*,*,形式,ケイシキ,ケイシキ
# です 助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。 記号,句点,*,*,*,*,。,。,。
# この 連体詞,*,*,*,*,*,この,コノ,コノ
# 場合 名詞,副詞可能,*,*,*,*,場合,バアイ,バアイ
# 、 記号,読点,*,*,*,*,、,、,、
# ` 名詞,サ変接続,*,*,*,*,*
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# よう 名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー
# な 助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# かたち 名詞,一般,*,*,*,*,かたち,カタチ,カタチ
# で 助詞,格助詞,一般,*,*,*,で,デ,デ
# 、 記号,読点,*,*,*,*,、,、,、
# 変数 名詞,一般,*,*,*,*,変数,ヘンスウ,ヘンスー
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 一部 名詞,副詞可能,*,*,*,*,一部,イチブ,イチブ
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 置換 名詞,サ変接続,*,*,*,*,置換,チカン,チカン
# でき 動詞,自立,*,*,一段,連用形,できる,デキ,デキ
# ます 助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。 記号,句点,*,*,*,*,。,。,。
# 置換 名詞,サ変接続,*,*,*,*,置換,チカン,チカン
# パラメータ 名詞,一般,*,*,*,*,パラメータ,パラメータ,パラメータ
# は 助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、 記号,読点,*,*,*,*,、,、,、
# 形式 名詞,一般,*,*,*,*,形式,ケイシキ,ケイシキ
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# カスタマイズ 名詞,一般,*,*,*,*,カスタマイズ,カスタマイズ,カスタマイズ
# する 動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# こと 名詞,非自立,一般,*,*,*,こと,コト,コト
# も 助詞,係助詞,*,*,*,*,も,モ,モ
# 可能 名詞,形容動詞語幹,*,*,*,*,可能,カノウ,カノー
# です 助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。 記号,句点,*,*,*,*,。,。,。
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# よう 名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー
# に 助詞,副詞化,*,*,*,*,に,ニ,ニ
# 定義 名詞,サ変接続,*,*,*,*,定義,テイギ,テイギ
# し 動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て 助詞,接続助詞,*,*,*,*,て,テ,テ
# 、 記号,読点,*,*,*,*,、,、,、
# 置換 名詞,サ変接続,*,*,*,*,置換,チカン,チカン
# する 動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# こと 名詞,非自立,一般,*,*,*,こと,コト,コト
# も 助詞,係助詞,*,*,*,*,も,モ,モ
# 可能 名詞,形容動詞語幹,*,*,*,*,可能,カノウ,カノー
# です 助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。 記号,句点,*,*,*,*,。,。,。
# この 連体詞,*,*,*,*,*,この,コノ,コノ
# 場合 名詞,副詞可能,*,*,*,*,場合,バアイ,バアイ
# は 助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、 記号,読点,*,*,*,*,、,、,、
# ` 名詞,サ変接続,*,*,*,*,*
# という 助詞,格助詞,連語,*,*,*,という,トイウ,トユウ
# かたち 名詞,一般,*,*,*,*,かたち,カタチ,カタチ
# で 助詞,格助詞,一般,*,*,*,で,デ,デ
# 置換 名詞,サ変接続,*,*,*,*,置換,チカン,チカン
# し 動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# ます 助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。 記号,句点,*,*,*,*,。,。,。
# 私 名詞,代名詞,一般,*,*,*,私,ワタシ,ワタシ
# は 助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、 記号,読点,*,*,*,*,、,、,、
# どちら 名詞,代名詞,一般,*,*,*,どちら,ドチラ,ドチラ
# か 助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# と 助詞,格助詞,引用,*,*,*,と,ト,ト
# いう 動詞,自立,*,*,五段・ワ行促音便,基本形,いう,イウ,イウ
# と 助詞,接続助詞,*,*,*,*,と,ト,ト
# 、 記号,読点,*,*,*,*,、,、,、
# こちら 名詞,代名詞,一般,*,*,*,こちら,コチラ,コチラ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 方 名詞,非自立,一般,*,*,*,方,ホウ,ホー
# が 助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 好み 名詞,一般,*,*,*,*,好み,コノミ,コノミ
# です 助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。 記号,句点,*,*,*,*,。,。,。
# 置換 名詞,サ変接続,*,*,*,*,置換,チカン,チカン
# パラメータ 名詞,一般,*,*,*,*,パラメータ,パラメータ,パラメータ
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 指定 名詞,サ変接続,*,*,*,*,指定,シテイ,シテイ
# する 動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# 際 名詞,非自立,副詞可能,*,*,*,際,サイ,サイ
# に 助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 、 記号,読点,*,*,*,*,、,、,、
# こちら 名詞,代名詞,一般,*,*,*,こちら,コチラ,コチラ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 方 名詞,非自立,一般,*,*,*,方,ホウ,ホー
# が 助詞,格助詞,一般,*,*,*,が,ガ,ガ
# パッ 副詞,助詞類接続,*,*,*,*,パッ,パッ,パッ
# と 助詞,副詞化,*,*,*,*,と,ト,ト
# 見た目 名詞,一般,*,*,*,*,見た目,ミタメ,ミタメ
# で 助詞,格助詞,一般,*,*,*,で,デ,デ
# 分かり 動詞,自立,*,*,五段・ラ行,連用形,分かる,ワカリ,ワカリ
# やすい 形容詞,非自立,*,*,形容詞・アウオ段,基本形,やすい,ヤスイ,ヤスイ
# 。 記号,句点,*,*,*,*,。,。,。
# さらに 副詞,助詞類接続,*,*,*,*,さらに,サラニ,サラニ
# 、 記号,読点,*,*,*,*,、,、,、
# テーブル 名詞,一般,*,*,*,*,テーブル,テーブル,テーブル
# 形式 名詞,一般,*,*,*,*,形式,ケイシキ,ケイシキ
# で 助詞,格助詞,一般,*,*,*,で,デ,デ
# 、 記号,読点,*,*,*,*,、,、,、
# 複数 名詞,一般,*,*,*,*,複数,フクスウ,フクスー
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 置換 名詞,サ変接続,*,*,*,*,置換,チカン,チカン
# パラメータ 名詞,一般,*,*,*,*,パラメータ,パラメータ,パラメータ
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 、 記号,読点,*,*,*,*,、,、,、
# まとめ 動詞,自立,*,*,一段,連用形,まとめる,マトメ,マトメ
# て 助詞,接続助詞,*,*,*,*,て,テ,テ
# 置換 名詞,サ変接続,*,*,*,*,置換,チカン,チカン
# する 動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# こと 名詞,非自立,一般,*,*,*,こと,コト,コト
# も 助詞,係助詞,*,*,*,*,も,モ,モ
# でき 動詞,自立,*,*,一段,連用形,できる,デキ,デキ
# ます 助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。 記号,句点,*,*,*,*,。,。,。
# ファイル 名詞,一般,*,*,*,*,ファイル,ファイル,ファイル
# から 助詞,格助詞,一般,*,*,*,から,カラ,カラ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 読み込み 名詞,一般,*,*,*,*,読み込み,ヨミコミ,ヨミコミ
# データ 名詞,一般,*,*,*,*,データ,データ,データ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 内容 名詞,一般,*,*,*,*,内容,ナイヨウ,ナイヨー
# が 助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 大きい 形容詞,自立,*,*,形容詞・イ段,基本形,大きい,オオキイ,オーキイ
# 場合 名詞,副詞可能,*,*,*,*,場合,バアイ,バアイ
# など 助詞,副助詞,*,*,*,*,など,ナド,ナド
# 、 記号,読点,*,*,*,*,、,、,、
# feature 名詞,固有名詞,組織,*,*,*,*
# ファイル 名詞,一般,*,*,*,*,ファイル,ファイル,ファイル
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 中 名詞,非自立,副詞可能,*,*,*,中,ナカ,ナカ
# で 助詞,格助詞,一般,*,*,*,で,デ,デ
# 指定 名詞,サ変接続,*,*,*,*,指定,シテイ,シテイ
# する 動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# の 名詞,非自立,一般,*,*,*,の,ノ,ノ
# は 助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、 記号,読点,*,*,*,*,、,、,、
# 手間 名詞,一般,*,*,*,*,手間,テマ,テマ
# かも 助詞,副助詞,*,*,*,*,かも,カモ,カモ
# しれ 動詞,自立,*,*,一段,連用形,しれる,シレ,シレ
# ませ 助動詞,*,*,*,特殊・マス,未然形,ます,マセ,マセ
# ん 助動詞,*,*,*,不変化型,基本形,ん,ン,ン
# 。 記号,句点,*,*,*,*,。,。,。
# そういう 連体詞,*,*,*,*,*,そういう,ソウイウ,ソーユウ
# 場合 名詞,副詞可能,*,*,*,*,場合,バアイ,バアイ
# に 助詞,格助詞,一般,*,*,*,に,ニ,ニ
# は 助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、 記号,読点,*,*,*,*,、,、,、
# ファイル 名詞,一般,*,*,*,*,ファイル,ファイル,ファイル
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 読み込ん 動詞,自立,*,*,五段・マ行,連用タ接続,読み込む,ヨミコン,ヨミコン
# で 助詞,接続助詞,*,*,*,*,で,デ,デ
# 、 記号,読点,*,*,*,*,、,、,、
# 利用 名詞,サ変接続,*,*,*,*,利用,リヨウ,リヨー
# する 動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# こと 名詞,非自立,一般,*,*,*,こと,コト,コト
# も 助詞,係助詞,*,*,*,*,も,モ,モ
# でき 動詞,自立,*,*,一段,連用形,できる,デキ,デキ
# ます 助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。 記号,句点,*,*,*,*,。,。,。
# たった 副詞,助詞類接続,*,*,*,*,たった,タッタ,タッタ
# 、 記号,読点,*,*,*,*,、,、,、
# これ 名詞,代名詞,一般,*,*,*,これ,コレ,コレ
# だけ 助詞,副助詞,*,*,*,*,だけ,ダケ,ダケ
# です 助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# 。 記号,句点,*,*,*,*,。,。,。
# ファイル 名詞,一般,*,*,*,*,ファイル,ファイル,ファイル
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 読み込み 名詞,一般,*,*,*,*,読み込み,ヨミコミ,ヨミコミ
# も 助詞,係助詞,*,*,*,*,も,モ,モ
# 簡単 名詞,形容動詞語幹,*,*,*,*,簡単,カンタン,カンタン
# です 助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# ね 助詞,終助詞,*,*,*,*,ね,ネ,ネ
# 。 記号,句点,*,*,*,*,。,。,。
# ただし 接続詞,*,*,*,*,*,ただし,タダシ,タダシ
# 、 記号,読点,*,*,*,*,、,、,、
# 指定 名詞,サ変接続,*,*,*,*,指定,シテイ,シテイ
# し 動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た 助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# ファイル 名詞,一般,*,*,*,*,ファイル,ファイル,ファイル
# は 助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、 記号,読点,*,*,*,*,、,、,、
# Karate 名詞,一般,*,*,*,*,*
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 実行 名詞,サ変接続,*,*,*,*,実行,ジッコウ,ジッコー
# する 動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# 際 名詞,非自立,副詞可能,*,*,*,際,サイ,サイ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# クラス 名詞,一般,*,*,*,*,クラス,クラス,クラス
# パス 名詞,サ変接続,*,*,*,*,パス,パス,パス
# に 助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 含ま 動詞,自立,*,*,五段・マ行,未然形,含む,フクマ,フクマ
# れ 動詞,接尾,*,*,一段,連用形,れる,レ,レ
# て 助詞,接続助詞,*,*,*,*,て,テ,テ
# いる 動詞,非自立,*,*,一段,基本形,いる,イル,イル
# 必要 名詞,形容動詞語幹,*,*,*,*,必要,ヒツヨウ,ヒツヨー
# が 助詞,格助詞,一般,*,*,*,が,ガ,ガ
# あり 動詞,自立,*,*,五段・ラ行,連用形,ある,アリ,アリ
# ます 助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。 記号,句点,*,*,*,*,。,。,。
# まとめ 名詞,一般,*,*,*,*,まとめ,マトメ,マトメ
# Karate 名詞,一般,*,*,*,*,*
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# データ 名詞,一般,*,*,*,*,データ,データ,データ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 定義 名詞,サ変接続,*,*,*,*,定義,テイギ,テイギ
# 方法 名詞,一般,*,*,*,*,方法,ホウホウ,ホーホー
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 確認 名詞,サ変接続,*,*,*,*,確認,カクニン,カクニン
# し 動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て 助詞,接続助詞,*,*,*,*,て,テ,テ
# み 動詞,非自立,*,*,一段,連用形,みる,ミ,ミ
# まし 助動詞,*,*,*,特殊・マス,連用形,ます,マシ,マシ
# た 助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# が 助詞,接続助詞,*,*,*,*,が,ガ,ガ
# 、 記号,読点,*,*,*,*,、,、,、
# 豊富 名詞,形容動詞語幹,*,*,*,*,豊富,ホウフ,ホーフ
# な 助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# 指定 名詞,サ変接続,*,*,*,*,指定,シテイ,シテイ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# 仕方 名詞,ナイ形容詞語幹,*,*,*,*,仕方,シカタ,シカタ
# が 助詞,格助詞,一般,*,*,*,が,ガ,ガ
# あり 動詞,自立,*,*,五段・ラ行,連用形,ある,アリ,アリ
# 、 記号,読点,*,*,*,*,、,、,、
# また 接続詞,*,*,*,*,*,また,マタ,マタ
# 、 記号,読点,*,*,*,*,、,、,、
# それぞれ 名詞,副詞可能,*,*,*,*,それぞれ,ソレゾレ,ソレゾレ
# ほぼ 副詞,一般,*,*,*,*,ほぼ,ホボ,ホボ
# コマンド 名詞,一般,*,*,*,*,コマンド,コマンド,コマンド
# ひとつ 名詞,副詞可能,*,*,*,*,ひとつ,ヒトツ,ヒトツ
# で 助詞,格助詞,一般,*,*,*,で,デ,デ
# 実現 名詞,サ変接続,*,*,*,*,実現,ジツゲン,ジツゲン
# さ 動詞,自立,*,*,サ変・スル,未然レル接続,する,サ,サ
# れ 動詞,接尾,*,*,一段,連用形,れる,レ,レ
# て 助詞,接続助詞,*,*,*,*,て,テ,テ
# おり 動詞,非自立,*,*,五段・ラ行,連用形,おる,オリ,オリ
# 、 記号,読点,*,*,*,*,、,、,、
# 簡単 名詞,形容動詞語幹,*,*,*,*,簡単,カンタン,カンタン
# に 助詞,副詞化,*,*,*,*,に,ニ,ニ
# 定義 名詞,サ変接続,*,*,*,*,定義,テイギ,テイギ
# できる 動詞,自立,*,*,一段,基本形,できる,デキル,デキル
# の 名詞,非自立,一般,*,*,*,の,ノ,ノ
# が 助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 良い 形容詞,自立,*,*,形容詞・アウオ段,基本形,良い,ヨイ,ヨイ
# と 助詞,格助詞,引用,*,*,*,と,ト,ト
# 思っ 動詞,自立,*,*,五段・ワ行促音便,連用タ接続,思う,オモッ,オモッ
# て 助詞,接続助詞,*,*,*,*,て,テ,テ
# い 動詞,非自立,*,*,一段,連用形,いる,イ,イ
# ます 助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。 記号,句点,*,*,*,*,。,。,。
# テスト 名詞,サ変接続,*,*,*,*,テスト,テスト,テスト
# シナリオ 名詞,一般,*,*,*,*,シナリオ,シナリオ,シナリオ
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 作成 名詞,サ変接続,*,*,*,*,作成,サクセイ,サクセイ
# する 動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# 上 名詞,非自立,副詞可能,*,*,*,上,ウエ,ウエ
# で 助詞,格助詞,一般,*,*,*,で,デ,デ
# 、 記号,読点,*,*,*,*,、,、,、
# これら 名詞,代名詞,一般,*,*,*,これら,コレラ,コレラ
# が 助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 変数 名詞,一般,*,*,*,*,変数,ヘンスウ,ヘンスー
# など 助詞,副助詞,*,*,*,*,など,ナド,ナド
# が 助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 簡単 名詞,形容動詞語幹,*,*,*,*,簡単,カンタン,カンタン
# に 助詞,副詞化,*,*,*,*,に,ニ,ニ
# 指定 名詞,サ変接続,*,*,*,*,指定,シテイ,シテイ
# できる 動詞,自立,*,*,一段,基本形,できる,デキル,デキル
# の 名詞,非自立,一般,*,*,*,の,ノ,ノ
# は 助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、 記号,読点,*,*,*,*,、,、,、
# 作業 名詞,サ変接続,*,*,*,*,作業,サギョウ,サギョー
# が 助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 効率 名詞,一般,*,*,*,*,効率,コウリツ,コーリツ
# 的 名詞,接尾,形容動詞語幹,*,*,*,的,テキ,テキ
# に 助詞,副詞化,*,*,*,*,に,ニ,ニ
# 進め 動詞,自立,*,*,一段,未然形,進める,ススメ,ススメ
# られる 動詞,接尾,*,*,一段,基本形,られる,ラレル,ラレル
# と 助詞,格助詞,引用,*,*,*,と,ト,ト
# お 接頭詞,名詞接続,*,*,*,*,お,オ,オ
# 見 動詞,自立,*,*,一段,連用形,見る,ミ,ミ
# ます 助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス
# 。 記号,句点,*,*,*,*,。,。,。
# より 助詞,格助詞,一般,*,*,*,より,ヨリ,ヨリ
# 、 記号,読点,*,*,*,*,、,、,、
# 詳しい 形容詞,自立,*,*,形容詞・イ段,基本形,詳しい,クワシイ,クワシイ
# 使い方 名詞,一般,*,*,*,*,使い方,ツカイカタ,ツカイカタ
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 調べる 動詞,自立,*,*,一段,基本形,調べる,シラベル,シラベル
# 場合 名詞,副詞可能,*,*,*,*,場合,バアイ,バアイ
# は 助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、 記号,読点,*,*,*,*,、,、,、
# 以下 名詞,非自立,副詞可能,*,*,*,以下,イカ,イカ
# の 助詞,連体化,*,*,*,*,の,ノ,ノ
# Karate 名詞,一般,*,*,*,*,*
# Demo 名詞,一般,*,*,*,*,*
# を 助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 参照 名詞,サ変接続,*,*,*,*,参照,サンショウ,サンショー
# する 動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# と 助詞,接続助詞,*,*,*,*,と,ト,ト
# 良い 形容詞,自立,*,*,形容詞・アウオ段,基本形,良い,ヨイ,ヨイ
# でしょ 助動詞,*,*,*,特殊・デス,未然形,です,デショ,デショ
# う 助動詞,*,*,*,不変化型,基本形,う,ウ,ウ
# 。 記号,句点,*,*,*,*,。,。,。
#  BOS/EOS,*,*,*,*,*,*,*,*

# %%
len(words)
# Out:
# 116

# %%
len(woo)
# Out:
# 401

# %%
hinshi_list = ['名詞','動詞','形容詞']

def get_words(content):
    node = tagger.parseToNode(content)
    words = []
    woo = []
    while node:
        pos, pos_sub1 = node.feature.split(',')[:2]
    #     print(pos, pos_sub1)
        if pos in hinshi_list:
            woo.append(node.surface)
        if pos == '名詞' and pos_sub1 in ('固有名詞', '一般'):
            words.append(node.surface)

#         print(node.surface, node.feature)
        node = node.next
    return words
    return woo

# %%
import numpy as np
df_header['text'][19] == np.nan
df_header['text'][19]
# Out:
# nan

# %%
df_header['text'][19].isnull()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-126-9da4d638b9a1> in <module>
# ----> 1 df_header['text'][19].isnull()
#
# AttributeError: 'float' object has no attribute 'isnull'

# %%
from collections import Counter

frequency = Counter()
num_docs = 0

for content in df_nonna['text'][:200]:
#     print(num_docs)
#     if np.isnan(df_header['text'][19]) == False:
    words = get_words(content)
    frequency.update(words)
#     print(num_docs)
    num_docs +=1

# %%
frequency
# Out:
# Counter({'モック': 1,
#          'シナリオ': 4,
#          '幅': 10,
#          'Karate': 4,
#          'データ': 161,
#          'リクエスト': 12,
#          '内容': 110,
#          'レスポンス': 8,
#          '方法': 106,
#          '変数': 87,
#          '基本': 40,
#          '値': 112,
#          '感じ': 65,
#          '日本語': 7,
#          'JSON': 21,
#          '形式': 19,
#          'REST': 10,
#          'API': 46,
#          '辺り': 7,
#          '使い勝手': 3,
#          'マルチ': 3,
#          'ライン': 6,
#          'コマンド': 137,
#          'テーブル': 13,
#          'table': 2,
#          'ネスト': 5,
#          '行': 31,
#          '列': 70,
#          'パラメータ': 53,
#          '上記': 49,
#          '文字': 91,
#          '一部分': 2,
#          '別': 16,
#          'デフォルト': 44,
#          'かたち': 3,
#          'カスタマイズ': 5,
#          '好み': 6,
#          '見た目': 9,
#          '複数': 57,
#          'ファイル': 259,
#          '読み込み': 7,
#          'feature': 10,
#          '手間': 11,
#          'クラス': 98,
#          'まとめ': 26,
#          '効率': 6,
#          '使い方': 42,
#          'Demo': 1,
#          '久々': 1,
#          'Qiita': 16,
#          '淫夢': 1,
#          '記事': 169,
#          'シェア': 2,
#          'Windows': 25,
#          'WSL': 4,
#          'bash': 8,
#          'notepad': 2,
#          'exe': 5,
#          'atom': 1,
#          'subl': 1,
#          'やり方': 11,
#          'ブログ': 5,
#          '簡易': 10,
#          '手順': 52,
#          '蛇足': 3,
#          'alias': 2,
#          'あかり': 1,
#          'Scala': 17,
#          'わり': 10,
#          '古': 1,
#          'ゲーム': 28,
#          'サーバー': 107,
#          'オマケ': 2,
#          'Node': 6,
#          'ツール': 49,
#          'イベント': 17,
#          'プレイヤー': 18,
#          '情報': 74,
#          'KPI': 1,
#          '各種': 8,
#          'ビジュアライズ': 2,
#          '生命': 1,
#          'Python': 85,
#          'システム': 37,
#          'タイトル': 35,
#          '実績': 5,
#          '差分': 7,
#          'ふたつ返事': 1,
#          'OK': 22,
#          'クローズド': 4,
#          '左うちわ': 1,
#          '抜本': 1,
#          'シビアー': 1,
#          'Season': 1,
#          'ロジック': 3,
#          'o': 5,
#          'トラフィック': 7,
#          'コード': 151,
#          '具体': 21,
#          '守秘': 1,
#          '義務': 1,
#          '対象': 40,
#          '機密': 1,
#          '事項': 3,
#          '最終': 15,
#          'k': 47,
#          'レベル': 23,
#          'ポエム': 1,
#          'ネタ': 8,
#          'Akka': 4,
#          'Actor': 2,
#          'FSM': 1,
#          'Remote': 1,
#          'データベース': 16,
#          'MongoDB': 15,
#          'KVS': 4,
#          'Redis': 25,
#          'DB': 37,
#          'ラッパー': 2,
#          'Lift': 3,
#          'メッシュ': 5,
#          'ロードバランサー': 1,
#          'クライアント': 53,
#          'TCP': 4,
#          '暗号': 24,
#          'チャット': 32,
#          'プロセス': 41,
#          'ロビー': 21,
#          'キャラクター': 21,
#          '座標': 16,
#          'ランキング': 4,
#          'アプリアカウント': 1,
#          'アイテム': 5,
#          'リスト': 38,
#          'サーバー・ロビーサーバー・チャットサーバー': 1,
#          'アカウント': 23,
#          '後ろ': 2,
#          '鍵': 16,
#          'ホスト': 25,
#          'ポート': 42,
#          '秒': 4,
#          'やりとり': 8,
#          '周囲': 10,
#          '返信': 10,
#          'チャットパーティーマッチング': 1,
#          '他人': 5,
#          '会社': 14,
#          'バイナリー': 2,
#          '本物': 2,
#          'Unreal': 1,
#          'Engine': 13,
#          'ビルド': 36,
#          'サイズ': 16,
#          'G': 3,
#          'クラ': 15,
#          'ウド': 12,
#          'インスタンス': 48,
#          'あたり': 9,
#          'マグマ': 1,
#          '真ん中': 4,
#          '目': 20,
#          '玉': 1,
#          '高値': 3,
#          'かなり': 4,
#          'コスト': 11,
#          'プアー': 1,
#          '同時': 7,
#          '頻度': 7,
#          '現象': 10,
#          'C': 68,
#          'S': 8,
#          '不成立': 1,
#          '状態': 43,
#          '内訳': 1,
#          'サーバーアプリ': 1,
#          '自分': 105,
#          'タイム': 9,
#          'アウト': 7,
#          'フリー': 1,
#          'テキスト': 18,
#          'NG': 11,
#          'ワード': 4,
#          'UX': 2,
#          '文言': 1,
#          'メッセージ': 21,
#          'バイト': 7,
#          'ネットワーク': 14,
#          'テストクライアント': 5,
#          '全員': 12,
#          'ログイン': 27,
#          'ユーザー': 36,
#          '数': 35,
#          '悲鳴': 1,
#          'リモートアクター': 1,
#          'ソリューション': 10,
#          '本件': 5,
#          '前回': 9,
#          'アクター': 5,
#          'orz': 3,
#          '興味': 15,
#          'メンバー': 7,
#          '総数': 4,
#          'プレイ': 3,
#          'それなり': 3,
#          '笑': 8,
#          '気': 27,
#          '事前': 8,
#          '申し込み': 1,
#          '最大': 22,
#          'わら': 2,
#          'クエリー': 3,
#          '絨毯': 1,
#          'オンメモリー': 2,
#          'キャッシュ': 8,
#          'チャットサーバーインスタンス': 1,
#          'ロード': 21,
#          'バランシング': 1,
#          'アルゴリズム': 11,
#          '前提': 21,
#          '構造': 48,
#          '焼け石': 1,
#          '民生': 1,
#          'ホース': 1,
#          '場': 10,
#          'オンライン': 3,
#          'にぎわい': 1,
#          '次': 58,
#          'トリガー': 2,
#          '部分': 78,
#          'メイン': 32,
#          'テーマ': 10,
#          '多': 2,
#          'バトル': 14,
#          '状況': 22,
#          'スロー': 10,
#          '現実': 4,
#          '時刻': 10,
#          '人': 71,
#          'セマフォー': 1,
#          '事象': 3,
#          'パラメーター': 10,
#          'ドキュメント': 25,
#          '乱数': 6,
#          '空': 27,
#          'ルーム': 10,
#          '条件': 30,
#          '例外': 12,
#          'スロークエリー': 3,
#          'ブロック': 54,
#          'コンテキスト': 5,
#          '実質': 2,
#          'スリープ': 1,
#          '理由': 21,
#          'パーティー': 13,
#          '単位': 14,
#          'オフライン': 1,
#          'モード': 16,
#          '個人': 21,
#          'リトライ': 1,
#          '限界': 1,
#          '思い': 4,
#          '業界': 1,
#          '古典': 3,
#          'オーナー': 3,
#          'スタイル': 2,
#          'いち': 1,
#          'お客様': 2,
#          '仕様': 10,
#          '取り合い': 1,
#          'メンテ': 3,
#          'ディスク': 16,
#          'コンス': 2,
#          'トラクター': 1,
#          'オーバーライド': 2,
#          'メソッド': 90,
#          'クォリティー': 1,
#          '最後': 33,
#          '愚痴': 1,
#          'm': 65,
#          'しよう': 4,
#          '非同期': 8,
#          'ライブラリー': 2,
#          '資源': 2,
#          '待ち': 2,
#          'ZSET': 4,
#          'キー': 36,
#          'ObjectId': 1,
#          'エポック': 1,
#          'Lua': 1,
#          'スクリプト': 30,
#          'アトミック': 4,
#          '冗長': 1,
#          '初期': 34,
#          'ラベル': 4,
#          '種類': 22,
#          '環境': 145,
#          '単一': 3,
#          'STRING': 5,
#          '中身': 20,
#          '本格': 4,
#          'リモート': 3,
#          '目処': 1,
#          '満': 1,
#          '漏れ': 1,
#          'バグ': 4,
#          '未曾有': 1,
#          '差': 11,
#          'ランダム': 1,
#          '間': 12,
#          '原則': 1,
#          'ぶん': 6,
#          '人数': 6,
#          '両者': 2,
#          '泣': 1,
#          '近傍': 4,
#          '大杉': 1,
#          '原因': 19,
#          '感覚': 3,
#          'いちど': 1,
#          'ログアウト': 2,
#          'スキーマ': 1,
#          '通常': 12,
#          '代物': 1,
#          '冒頭': 6,
#          'HASH': 3,
#          'トップ': 4,
#          '形': 24,
#          '相手': 33,
#          '密': 1,
#          '台数': 1,
#          'じたい': 2,
#          '手法': 26,
#          'nonce': 2,
#          'ライフ': 4,
#          '一因': 1,
#          'ポーリング': 1,
#          'タイミング': 11,
#          '粒': 1,
#          '従前': 1,
#          'メンテナンス': 17,
#          'フロント': 3,
#          'エンド': 8,
#          'httpd': 5,
#          'あと': 38,
#          'season': 1,
#          '意気揚々': 1,
#          '休み': 2,
#          'バックグラウンド': 1,
#          '週': 4,
#          '翌週': 2,
#          '頭': 7,
#          '流れ': 11,
#          '勘': 2,
#          '他': 44,
#          '謎': 2,
#          '期限': 4,
#          'トップレベルキー': 1,
#          'オチ': 1,
#          'or': 13,
#          '多重': 2,
#          'チート': 1,
#          '目的': 27,
#          '局面': 1,
#          'git': 17,
#          'バージョン': 38,
#          'はるか': 1,
#          '時点': 11,
#          'ゴミ': 4,
#          '崖': 1,
#          '涙': 3,
#          'リビルド': 1,
#          'リフレクション': 1,
#          '単体テスト': 2,
#          'ー': 9,
#          '知見': 2,
#          '目標': 7,
#          'チューニング': 7,
#          'ボトルネック': 1,
#          '型付き': 1,
#          '禁句': 1,
#          'NoSQL': 1,
#          '規模': 3,
#          'クライアントライブラリー': 1,
#          '箇所': 10,
#          'パフォーマンス': 3,
#          'ラッパークラス': 1,
#          '面': 2,
#          '感想': 7,
#          '本質': 4,
#          '出し': 1,
#          'ジャンケン': 1,
#          '見立て': 1,
#          '機会': 6,
#          'ノウハウ': 2,
#          '現職': 4,
#          'LAMP': 1,
#          'スマホゲーム': 1,
#          'チーム': 14,
#          '感触': 1,
#          'コンシューマー': 1,
#          'アーケード': 1,
#          'むかし': 1,
#          '字': 2,
#          '世界': 10,
#          '抜き': 1,
#          '問い': 1,
#          '組み合わせ': 13,
#          'きっかけ': 9,
#          '風評': 1,
#          '視点': 8,
#          '労力': 1,
#          '性能': 4,
#          'バランス': 1,
#          'プロダクツ': 2,
#          '最新': 11,
#          '現状': 3,
#          'ちゃぶ台': 1,
#          'Oracle': 6,
#          '地主': 1,
#          '制度': 1,
#          'エンジニアー': 4,
#          'ついで': 3,
#          '案件': 6,
#          '傾向': 2,
#          'JVM': 2,
#          '差異': 2,
#          'ばか': 1,
#          '耳': 3,
#          'かも': 1,
#          'フェーズ': 1,
#          'GC': 2,
#          'リスク': 2,
#          'パブリッシャー': 1,
#          'ビジネス': 3,
#          '形而上': 1,
#          '業務': 7,
#          'Web': 34,
#          'ベンチャー': 1,
#          '基幹': 1,
#          '職場': 2,
#          'うち': 2,
#          '最悪': 2,
#          'CTO': 1,
#          '種': 1,
#          'プロ': 11,
#          'dis': 1,
#          '定番': 1,
#          'SNS': 1,
#          '糞': 6,
#          'ほんとう': 2,
#          '概念': 10,
#          '画面': 63,
#          '過程': 5,
#          '内情': 1,
#          'コンピューター': 1,
#          '目線': 1,
#          'UDP': 3,
#          'オプション': 43,
#          'スター': 4,
#          '中心': 5,
#          'エンジン': 4,
#          '余地': 2,
#          '一連': 2,
#          'シーケンス': 3,
#          'リアルガチ': 1,
#          '過疎': 2,
#          'たら': 1,
#          'ご存じ': 1,
#          '品質': 1,
#          '地域': 6,
#          '無条件': 2,
#          '中': 4,
#          '隣': 3,
#          'アメリカ': 2,
#          'ドイツ': 1,
#          '帯域': 1,
#          '実害': 1,
#          '段階': 18,
#          '宿命': 1,
#          '技術': 17,
#          '脚注': 2,
#          '権利': 1,
#          'タテマエ': 1,
#          'Issue': 3,
#          '誰か': 2,
#          '定期': 5,
#          'ブラッシュ': 2,
#          '見直し': 2,
#          '習慣': 1,
#          'コストパフォーマンス': 1,
#          'いね': 2,
#          '引き金': 1,
#          '事例': 13,
#          '例': 85,
#          '言葉': 17,
#          '響き': 1,
#          'スティッキー': 1,
#          'ググ': 7,
#          'キーワード': 5,
#          '基準': 8,
#          '画像': 64,
#          '誤り': 3,
#          '根本': 1,
#          '心理': 1,
#          '言い回し': 2,
#          'チャンス': 1,
#          '本題': 3,
#          'テイスト': 1,
#          '読み物': 1,
#          'テイ': 1,
#          'スト': 1,
#          'トピック': 1,
#          'ノリ': 1,
#          'サイコ': 1,
#          'オッケー': 1,
#          '苦': 1,
#          '任天堂': 1,
#          '精度': 3,
#          '有意': 1,
#          'URL': 35,
#          '直': 3,
#          'ページ': 48,
#          'twitter': 5,
#          'アプリ': 37,
#          '備忘録': 11,
#          'controller': 1,
#          'before': 1,
#          'action': 1,
#          'correct': 4,
#          'user': 8,
#          '下記': 58,
#          'edit': 4,
#          'update': 1,
#          'アクション': 3,
#          'トップページ': 1,
#          'リダイレクト': 6,
#          'current': 1,
#          'ヘルパー': 4,
#          '名前': 44,
#          'サウンド': 3,
#          'NET': 3,
#          'メモリー': 1,
#          'ストリーム': 4,
#          '音声': 7,
#          '波形': 4,
#          'リアルタイム': 3,
#          '領域': 18,
#          '大抵': 3,
#          'プラットフォーム': 7,
#          'Advent': 1,
#          'Calender': 1,
#          'P': 3,
#          'Invoke': 1,
#          '自動': 32,
#          'バインディング': 1,
#          'libsoundio': 7,
#          'sharp': 4,
#          '自体': 11,
#          'リポジトリ': 27,
#          'オリジナル': 1,
#          'ネイティブ': 4,
#          'DLL': 3,
#          '本体': 7,
#          'Linux': 20,
#          'macos': 1,
#          'バイナリ': 5,
#          'サイト': 63,
#          '済': 5,
#          'submodule': 2,
#          '自前': 2,
#          'mingw': 1,
#          'Visual': 13,
#          'Studio': 13,
#          'CMake': 3,
#          'Installer': 1,
#          'コンポーネント': 37,
#          'VS': 4,
#          'external': 3,
#          'CMakeLists': 1,
#          'txt': 12,
#          'src': 17,
#          'unistd': 1,
#          'h': 19,
#          'soundio': 5,
#          '先頭': 13,
#          'CMAKE': 1,
#          'dll': 17,
#          'x': 117,
#          'Debug': 2,
#          'Release': 1,
#          'USERPROFILE': 1,
#          'CMakeBuilds': 1,
#          'ID': 24,
#          'build': 11,
#          '下': 28,
#          '規約': 3,
#          'DllImport': 1,
#          'delegate': 1,
#          'cdecl': 1,
#          '一つ': 31,
#          '手': 19,
#          'トラブル': 4,
#          'スルー': 1,
#          'サンプル': 36,
#          'sln': 1,
#          '場所': 25,
#          '音': 6,
#          'sio': 2,
#          'sine': 2,
#          'example': 6,
#          'bin': 20,
#          'Hz': 2,
#          'F': 14,
#          'SoundIOOutStreamUtil': 1,
#          'Play': 10,
#          'PlaySound': 1,
#          'Enumerator': 1,
#          'スレッドロック': 1,
#          '関数': 114,
#          '任意': 18,
#          '引数': 46,
#          'わかりやすさ': 1,
#          '方向': 14,
#          '背景': 6,
#          'プログラマ': 4,
#          '顧客': 3,
#          '仲間': 1,
#          '打ち合わせ': 2,
#          '御用': 2,
#          '声': 7,
#          '成果': 2,
#          '口頭': 1,
#          '会場': 4,
#          '外': 5,
#          'ご存知': 3,
#          'みえ': 1,
#          '最初': 34,
#          '係員': 2,
#          '本当': 2,
#          '職安': 1,
#          'ハローワーク': 1,
#          'エンジニア': 15,
#          '朝会': 1,
#          '役': 1,
#          '道具': 8,
#          '要点': 13,
#          'Use': 2,
#          'half': 1,
#          'the': 107,
#          'time': 2,
#          'for': 59,
#          'your': 7,
#          'partner': 1,
#          's': 38,
#          'interest': 1,
#          'ウィンウィン': 1,
#          '年齢': 6,
#          '異性': 1,
#          '本人': 1,
#          '虚実': 1,
#          '話題': 5,
#          'XX': 1,
#          '合いの手': 1,
#          'Let': 3,
#          'give': 1,
#          'priority': 1,
#          'to': 42,
#          'solution': 1,
#          'of': 45,
#          'what': 1,
#          'other': 5,
#          'person': 1,
#          'is': 64,
#          'in': 44,
#          'trouble': 1,
#          'ねこ': 3,
#          '秘話': 1,
#          'NSCPICE': 1,
#          '行事': 1,
#          'Line': 1,
#          'Stamp': 2,
#          '材料': 2,
#          '発端': 2,
#          '筋書き': 1,
#          '素案': 1,
#          '粗筋': 1,
#          '著者': 2,
#          'ことば': 2,
#          'いも': 1,
#          'びのおくりもの': 1,
#          'record': 2,
#          'different': 6,
#          'wording': 1,
#          'between': 5,
#          'one': 7,
#          'and': 56,
#          'you': 12,
#          '時代': 3,
#          '立場': 4,
#          '助け': 2,
#          'python': 19,
#          '機械': 13,
#          '上位': 4,
#          '下位': 2,
#          '類語': 2,
#          '辞書': 9,
#          'thesaurus': 1,
#          '同音': 1,
#          '異義': 1,
#          'イントネーション': 2,
#          '相槌': 5,
#          'experience': 2,
#          'CMM': 1,
#          'Trainer': 1,
#          '息子': 3,
#          '絵本': 1,
#          '英語': 10,
#          '固有名詞': 1,
#          '日常': 2,
#          '用語': 4,
#          '数学': 3,
#          '言語': 29,
#          'Java': 10,
#          '囲碁': 2,
#          'talk': 1,
#          'about': 3,
#          'tools': 1,
#          '金額': 2,
#          '極意': 2,
#          '清水': 2,
#          '吉男': 2,
#          'VZ': 1,
#          'エディタ': 16,
#          'アセンブラ': 2,
#          'ソース': 64,
#          '気持ち': 7,
#          'understand': 1,
#          'another': 2,
#          'view': 6,
#          '仕草': 3,
#          '視線': 3,
#          '物理': 9,
#          '姿勢': 5,
#          '熱意': 3,
#          '体系': 3,
#          '精神': 5,
#          'cherish': 1,
#          'a': 91,
#          'mental': 1,
#          'attitude': 1,
#          'such': 2,
#          'as': 10,
#          'enthusiasm': 1,
#          'seriousness': 1,
#          'systematic': 1,
#          'response': 1,
#          'Rather': 1,
#          'than': 2,
#          'physical': 1,
#          'attitudes': 1,
#          'appearance': 1,
#          'gesture': 1,
#          'gaze': 1,
#          'voice': 1,
#          'etc': 17,
#          '最低限': 10,
#          'スーツ': 1,
#          'ネクタイ': 1,
#          '技法': 2,
#          'Know': 1,
#          'How': 1,
#          '本': 12,
#          '街灯': 4,
#          '腕章': 2,
#          'AHC': 1,
#          'Axxxxxxx': 1,
#          'highscool': 1,
#          'Housou': 1,
#          'Club': 1,
#          '文献': 6,
#          'reference': 3,
#          'NHK': 2,
#          '読本': 1,
#          'Extra': 4,
#          'story': 1,
#          'テレコ': 1,
#          'tape': 1,
#          'recorder': 1,
#          'made': 1,
#          'by': 17,
#          'Sony': 1,
#          '駅頭': 1,
#          '千葉': 1,
#          '東京': 2,
#          '神奈川': 1,
#          '愛知': 1,
#          '逆': 8,
#          '電車': 1,
#          '余裕': 3,
#          '暇つぶし': 1,
#          '公園': 2,
#          '駅前': 1,
#          'training': 6,
#          'method': 5,
#          '趣味': 3,
#          '書類': 1,
#          '言い換え': 1,
#          'no': 6,
#          'hobby': 1,
#          'インタネット': 1,
#          'テレビ': 13,
#          '家': 3,
#          '学校': 2,
#          '教科': 1,
#          'クラブ': 1,
#          'No': 4,
#          'design': 1,
#          'document': 6,
#          '図': 11,
#          '新人': 5,
#          '教材': 3,
#          'マニュアル': 4,
#          'ヘルプ': 2,
#          '日報': 1,
#          '週報': 1,
#          '追伸': 2,
#          'post': 1,
#          'script': 2,
#          '題材': 3,
#          '動画': 9,
#          'ミスマープル': 2,
#          '課題': 15,
#          'アガサクリスティ': 1,
#          'ポワロ': 1,
#          '媒体': 1,
#          '時計': 3,
#          'ポアロ': 1,
#          '警察': 1,
#          '後回し': 2,
#          '文書': 10,
#          '履歴': 6,
#          'history': 2,
#          'ver': 17,
#          '初稿': 2,
#          '見出し': 5,
#          '順番': 14,
#          '本文': 14,
#          'ロ': 1,
#          '項目': 47,
#          '題': 4,
#          'Firebase': 3,
#          'Hosting': 2,
#          'ドメイン': 11,
#          'SSL': 9,
#          '無料': 10,
#          'Encrypt': 1,
#          'BitScheduler': 2,
#          '出欠': 2,
#          'Google': 31,
#          'カレンダー': 1,
#          '版': 1,
#          'Any': 3,
#          'Desk': 2,
#          'remote': 4,
#          'desktop': 5,
#          'software': 1,
#          'provides': 2,
#          'bidirectional': 2,
#          'access': 2,
#          'personal': 2,
#          'computers': 2,
#          'having': 1,
#          'operating': 1,
#          'system': 1,
#          'Mac': 31,
#          'windows': 3,
#          'linux': 4,
#          'It': 4,
#          'has': 5,
#          'several': 1,
#          'features': 3,
#          'like': 1,
#          'first': 2,
#          'that': 12,
#          'it': 8,
#          'allow': 3,
#          'In': 6,
#          'this': 20,
#          'communication': 2,
#          'need': 2,
#          'computer': 2,
#          'Anydesk': 1,
#          'address': 3,
#          '概要': 33,
#          'rpi': 1,
#          'y': 6,
#          'rt': 2,
#          'ぱい': 1,
#          'フォーラム': 1,
#          'PREEMPT': 1,
#          'RT': 1,
#          'ブランチ': 3,
#          'カーネル': 20,
#          'Raspberry': 17,
#          'Pi': 16,
#          'Raspbian': 6,
#          'ベース': 13,
#          'TL': 3,
#          'DR': 1,
#          '通り': 38,
#          'アーカイブ': 2,
#          'テストツールビルド': 1,
#          'Auth': 2,
#          'オリジン': 1,
#          'Embedded': 1,
#          'login': 4,
#          'web': 12,
#          'uses': 5,
#          'Cross': 1,
#          'Origin': 1,
#          'Authentication': 6,
#          'which': 6,
#          'does': 2,
#          'not': 10,
#          'work': 11,
#          'reliably': 1,
#          'on': 53,
#          'all': 9,
#          'browsers': 1,
#          'if': 25,
#          'do': 2,
#          'enable': 4,
#          'Custom': 6,
#          'Domains': 3,
#          'The': 9,
#          'use': 8,
#          'paid': 1,
#          'A': 62,
#          'good': 2,
#          'alternative': 1,
#          'migrate': 2,
#          'Universal': 2,
#          'Login': 3,
#          'cannot': 2,
#          'application': 8,
#          'Lock': 1,
#          'Widget': 1,
#          'embedded': 2,
#          '有料': 2,
#          'カスタム': 10,
#          'クロスドメインアクセス': 1,
#          'リモコン': 17,
#          'ボタン': 41,
#          'リピート': 1,
#          'ビット': 3,
#          '人物': 2,
#          'B': 42,
#          'with': 21,
#          'stretch': 2,
#          '赤外線': 4,
#          '出自': 1,
#          'LIRC': 3,
#          'c': 14,
#          'サマリー': 2,
#          'セットアップ': 13,
#          'ディスプレイ': 3,
#          'インストール': 144,
#          'zip': 7,
#          'img': 22,
#          'フォーマット': 16,
#          'SD': 4,
#          'カード': 10,
#          '書き込み': 3,
#          'ルート': 13,
#          'ssh': 7,
#          '階層': 5,
#          'wpa': 1,
#          'supplicant': 1,
#          'conf': 16,
#          '電源': 5,
#          'Wi': 4,
#          'Fi': 4,
#          'ルータ': 6,
#          'DHCP': 1,
#          '払出': 1,
#          'IP': 22,
#          'MAC': 1,
#          'Advanced': 1,
#          'Options': 1,
#          'Expand': 1,
#          'Filesystem': 1,
#          '正面': 3,
#          '右': 19,
#          '足': 3,
#          'V': 28,
#          'GND': 2,
#          '左': 16,
#          'GPIO': 11,
#          'カレント': 2,
#          'lircd': 2,
#          ...})

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Hiragino Maru Gothic Pro', 'Yu Gothic', 'Meirio', 'Takao', 'IPAexGothic', 'IPAPGothic', 'VL PGothic', 'Noto Sans CJK JP']

# TOP20のグラフ           
x = range(100)
mc = frequency.most_common(200)              # 頻度TOP20を抽出
ch = [ch[0] for ch in mc]           # ひらがなのリスト
f = np.array([ch[1] for ch in mc])  # 頻度の数値のリスト




plt.bar(x, f) 
plt.xticks(x, ch)  #日本語表示はfontproperties=fp
plt.title("名詞頻度 TOP20")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e7054308603a> in <module>
#       8 # TOP20のグラフ
#       9 x = range(100)
# ---> 10 mc = frequency.most_common(200)              # 頻度TOP20を抽出
#      11 ch = [ch[0] for ch in mc]           # ひらがなのリスト
#      12 f = np.array([ch[1] for ch in mc])  # 頻度の数値のリスト
#
# NameError: name 'frequency' is not defined

# %%
ch
# Out:
# ['ファイル',
#  'mathbf',
#  'i',
#  '記事',
#  'データ',
#  'コード',
#  '環境',
#  'インストール',
#  'コマンド',
#  'x',
#  '関数',
#  '値',
#  'j',
#  '内容',
#  'サーバー',
#  'the',
#  '方法',
#  '自分',
#  '要素',
#  'クラス',
#  'タグ',
#  'M',
#  '文字',
#  'a',
#  'メソッド',
#  '変数',
#  'Python',
#  '例',
#  'X',
#  '部分',
#  'D',
#  '情報',
#  '人',
#  '型',
#  'Docker',
#  '列',
#  'ライブラリ',
#  'C',
#  't',
#  '感じ',
#  'm',
#  '画像',
#  'is',
#  'ソース',
#  'bmatrix',
#  '画面',
#  'サイト',
#  'A',
#  'end',
#  'begin',
#  'docker',
#  'for',
#  'オブジェクト',
#  'hat',
#  '次',
#  '下記',
#  '複数',
#  'and',
#  'ブロック',
#  'p',
#  'パラメータ',
#  'クライアント',
#  'on',
#  '手順',
#  'プロジェクト',
#  'HTML',
#  'I',
#  '上記',
#  'ツール',
#  'インスタンス',
#  '構造',
#  'ページ',
#  'k',
#  '項目',
#  'n',
#  'API',
#  '引数',
#  'モデル',
#  'v',
#  'パスワード',
#  'of',
#  'AWS',
#  'デフォルト',
#  '他',
#  '名前',
#  'in',
#  'モジュール',
#  '状態',
#  'オプション',
#  'フォルダ',
#  'クリック',
#  'アプリケーション',
#  '使い方',
#  'ポート',
#  'to',
#  'B',
#  'プロパティ',
#  'プロセス',
#  'ボタン',
#  'top',
#  'html',
#  '基本',
#  '対象',
#  'ライセンス',
#  'リスト',
#  'あと',
#  'バージョン',
#  's',
#  '通り',
#  'システム',
#  'DB',
#  'アプリ',
#  'コンポーネント',
#  '数字',
#  'Cloud',
#  'ビルド',
#  'ユーザー',
#  'キー',
#  'サンプル',
#  'nav',
#  'タイトル',
#  '数',
#  'URL',
#  'コンテナ',
#  '初期',
#  'Web',
#  '最初',
#  'パッケージ',
#  'イン',
#  'Ctrl',
#  '最後',
#  '相手',
#  '概要',
#  'function',
#  'カテゴリ',
#  'チャット',
#  'メイン',
#  '自動',
#  'ディレクトリ',
#  'OS',
#  '行',
#  '一つ',
#  'Google',
#  'Mac',
#  'ノード',
#  '範囲',
#  'デプロイ',
#  'py',
#  'times',
#  'ペア',
#  'LGPL',
#  '条件',
#  'スクリプト',
#  'data',
#  'グループ',
#  '部下',
#  'Pro',
#  'align',
#  'ADPi',
#  '言語',
#  '文',
#  'var',
#  'サーバ',
#  'Unity',
#  '絵文字',
#  'ゲーム',
#  '下',
#  'V',
#  'ルール',
#  '番号',
#  'sum',
#  'r',
#  'aligned',
#  'ログイン',
#  '気',
#  '空',
#  '目的',
#  'リポジトリ',
#  'ブラウザ',
#  'msg',
#  'Builder',
#  'R',
#  'まとめ',
#  '手法',
#  'Ubuntu',
#  '属性',
#  'ソート',
#  'Windows',
#  'Redis',
#  'ホスト',
#  'ドキュメント',
#  '場所',
#  'if',
#  'メニュー',
#  '暗号',
#  '形',
#  'ID',
#  'レベル',
#  'アカウント',
#  'テンプレート']

# %%
# ライブラリのインポート
# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from bs4 import BeautifulSoup
import requests
import MeCab as mc

# %%
def mecab_analysis(text):
#     t = mc.Tagger('-Ochasen -d /usr/local/Cellar/mecab/0.996/lib/mecab/dic/mecab-ipadic-neologd/')
    t = MeCab.Tagger()
#     enc_text = text.encode('utf-8') 
    node = t.parseToNode(text) 
    output = []
    while(node):
        if node.surface != "":  # ヘッダとフッタを除外
            word_type = node.feature.split(",")[0]
            if word_type in ["形容詞", "動詞","名詞", "副詞"]:
                output.append(node.surface)
        node = node.next
        if node is None:
            break
    return output

# %%
def get_wordlist_from_QiitaURL(url):
    res = requests.get(url)
    soup = BeautifulSoup(res.text)
    text = soup.body.section.get_text().replace('\n','').replace('\t','')
    return mecab_analysis(text)

# %%
def create_wordcloud(text):

    # 環境に合わせてフォントのパスを指定する。
    fpath = "/System/Library/Fonts/ヒラギノ角ゴシック W3.ttc"
#     fpath = "/Library/Fonts/ヒラギノ角ゴ Pro W3.otf"
#     fpath = "/Library/Fonts/Menlo for Powerline.ttf"

    # ストップワードの設定
    stop_words = [ u'てる', u'いる', u'なる', u'れる', u'する', u'ある', u'こと', u'これ', u'さん', u'して', \
             u'くれる', u'やる', u'くださる', u'そう', u'せる', u'した',  u'思う',  \
             u'それ', u'ここ', u'ちゃん', u'くん', u'', u'て',u'に',u'を',u'は',u'の', u'が', u'と', u'た', u'し', u'で', \
             u'ない', u'も', u'な', u'い', u'か', u'ので', u'よう', u'']

    wordcloud = WordCloud(background_color="white",font_path=fpath, width=900, height=500, \
                          stopwords=set(stop_words)).generate(text)

    plt.figure(figsize=(15,12))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()

# %%
wordlist = mecab_analysis(df_header['text'][6])
# print(wordlist) 
create_wordcloud(" ".join(wordlist))

# %%
df_header['text'][0]
# Out:
# 'はじめには、モックのサービスを作成して、実際にシナリオテストを実施してみました。今回は、テストの幅を広げるために、Karateで、どのようにデータの定義をするのかを確認してみます。テスト実施時に、リクエストの内容を指定したり、レスポンスの内容を確認したりするために、どのようにデータを定義するのか、ということになります。データの指定方法変数の指定まずは、基本的な定義として、変数での指定をしてみます。が、変数の定義です。 は、テスト実行時に、レポートに変数の内容を出力してくれます。 は、値の確認です。実行したときのレポートの内容は、以下のような感じです。問題なく、テストが通っていますね。当然ながら、日本語も問題なく利用できます。JSON形式のデータの指定次は、JSONデータの指定方法について確認します。REST-APIのテストに向けては、この辺りの使い勝手は重要ですね。基本的な指定の仕方として、マルチラインでの指定です。 で囲むことによって、マルチラインでのデータの指定ができています。先程指定した  のデータの一部を変更しています。コマンドを利用することで、データを変更できます。今度は、テーブル形式でのJSONデータの指定です。 コマンドを指定して定義しています。生のJSONデータよりも、こちらの方が見やすいですね。ただ、tableの場合、ネストされているようなJSONは定義できません。ネストされたJSONデータを定義したい場合は、コマンドを利用することで可能です。こちらも、テーブル形式に近い内容ですが、のときと比べて、行と列の指定が入れ替わっていることに注意してください。テストの実行結果は、以下のようになります。指定したデータの内容も確認できて、分かりやすいです。パラメータの置換上記で、コマンドを利用した変数の値の変換を実施しましたが、指定した変数の一部を置き換えるようなこと（例えば、文字列の一部分を変更した場合など）はできません。そのような置換としては、別の方法があります。コマンドを利用すると、予め置換変数を指定しておき、それを指定した値で置換するようなことが可能です。デフォルトの変数は、 という形式です。この場合、` のようなかたちで、変数の一部を置換できます。置換パラメータは、形式をカスタマイズすることも可能です。 のように定義して、置換することも可能です。この場合は、` というかたちで置換します。私は、どちらかというと、こちらの方が好みです。置換パラメータを指定する際に、こちらの方がパッと見た目で分かりやすい。さらに、テーブル形式で、複数の置換パラメータを、まとめて置換することもできます。ファイルからの読み込みデータの内容が大きい場合など、featureファイルの中で指定するのは、手間かもしれません。そういう場合には、ファイルを読み込んで、利用することもできます。たった、これだけです。ファイルの読み込みも簡単ですね。ただし、指定したファイルは、Karateを実行する際のクラスパスに含まれている必要があります。まとめKarateのデータの定義方法を確認してみましたが、豊富な指定の仕方があり、また、それぞれほぼコマンドひとつで実現されており、簡単に定義できるのが良いと思っています。テストシナリオを作成する上で、これらが変数などが簡単に指定できるのは、作業が効率的に進められるとお見ます。より、詳しい使い方を調べる場合は、以下の Karate Demo を参照すると良いでしょう。'
